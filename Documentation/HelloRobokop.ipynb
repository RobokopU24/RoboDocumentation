# %%
import requests
import json

# %% [markdown]
# TRAPI Documentation: https://github.com/NCATSTranslator/ReasonerAPI
#
# Most TRAPI documents contain a `message` key.  Within that `message` are a `query_graph` denoting the user query,
# a `knowledge_graph` consisting of the union of all nodes and edges that match the `query_graph` pattern, and a list of `results` that bind `query_graph` elements to `knowledge_graph` elements.
#
# The following message contains only a `query_graph`.  This query graph consists of 3 nodes connected together in a line.   Two of the nodes (`n00` and `n02`) have specified identifiers, while the middle node of the line does not.  Rather the middle node has a list of `categories` that are acceptable.
#
# This query asks "Find me a Biological Process or Activity, or a Gene, or a Pathway that is related to both `PUBCHEM.COMPOUND:644073` (Buprenorphine) and `HP:0001337` (Tremor).

# %%
query={
    "message": {
      "query_graph": {
        "edges": {
          "e00": {
            "subject": "n00",
              "object": "n01",
          "predicates":["biolink:related_to"]
          },
          "e01": {
            "subject": "n01",
              "object": "n02",
          "predicates":["biolink:related_to"]
          }
        },
        "nodes": {
          "n00": {
            "ids": ["PUBCHEM.COMPOUND:644073"],
            "categories": ["biolink:ChemicalEntity"]
          },
          "n01": {
              "categories": ["biolink:BiologicalProcessOrActivity","biolink:Gene","biolink:Pathway"]
          },
          "n02": {
            "ids": ["HP:0001337"],
            "categories": ["biolink:DiseaseOrPhenotypicFeature"]
          }
        }
      }
    }
  }

# %% [markdown]
# This query can be sent to various components of Translator as needed.  It can be sent directly to the ROBOKOP database like this:

# %%
robokop_submit_url = "https://automat.renci.org/robokopkg/1.3/query"
response = requests.post(robokop_submit_url,json=query)

# %%
print(response.status_code)
# Out:
# 200

# %%
print(len(response.json()['message']['results']))
# Out:
# 7

# %%
import pprint
pp = pprint.PrettyPrinter(indent=5)

# %% [markdown]
# The response in JSON form is a python dictionary with three main keys, the `message`, `log_level`, and `workflow`.  The `message` component contains the `query_graph` from the input query, ROBOKOP has added `knowledge_graph`, and `results` which in combination contain the answer to the query graph.

# %%
print(response.json().keys())
print(response.json()['message'].keys())
# Out:
# dict_keys(['message', 'log_level', 'workflow'])
# dict_keys(['query_graph', 'knowledge_graph', 'results'])

# %% [markdown]
# The `results` component contains pathways resulting from the query message. Each pathway is organized into edge_bindings and node bindings and contains identifiers that map to the query elements.  For instance in the query below, ROBOKOP has associate the query node `n01` with the identifier `NCBIGene:1565`. All of the information about these identifiers, such as name, properties, or sources can be found in the `knowledge_graph` component of the `message` section of the response.

# %%
pp.pprint(response.json()['message']['results'][0])
# Out:
# {    'edge_bindings': {    'e00': [    {'attributes': None, 'id': '29599157'},
#                                        {'attributes': None, 'id': '117577598'},
#                                        {'attributes': None, 'id': '8921721'}],
#                            'e01': [{'attributes': None, 'id': '134555909'}]},
#      'node_bindings': {    'n00': [    {    'attributes': None,
#                                             'id': 'PUBCHEM.COMPOUND:644073',
#                                             'qnode_id': 'PUBCHEM.COMPOUND:644073',
#                                             'query_id': None}],
#                            'n01': [    {    'attributes': None,
#                                             'id': 'NCBIGene:1565',
#                                             'query_id': None}],
#                            'n02': [    {    'attributes': None,
#                                             'id': 'HP:0002174',
#                                             'qnode_id': 'HP:0001337',
#                                             'query_id': None}]},
#      'score': None}

# %% [markdown]
# The `knowledge_graph` contains information about each of the Nodes and Edges found in `results`.  An example of a Node and an Edge are shown below.

# %%
pp.pprint(response.json()['message']['knowledge_graph'].keys())
# Out:
# dict_keys(['nodes', 'edges'])

# %% [markdown]
# Information returned for the each Node includes the concept ID (key), biolink categories, the name/label, attributes, the value type, and others.  Note that each entry under the `nodes` level is itemized in dictionary format and not lists.  The content for one Node is shown below.

# %%
next(iter( response.json()['message']['knowledge_graph']['nodes'].items() ))
# Out:
# ('HP:0012164',
#  {'categories': ['biolink:PhenotypicFeature',
#    'biolink:Entity',
#    'biolink:ThingWithTaxon',
#    'biolink:BiologicalEntity',
#    'biolink:NamedThing',
#    'biolink:DiseaseOrPhenotypicFeature'],
#   'name': 'Asterixis',
#   'attributes': [{'attribute_type_id': 'biolink:same_as',
#     'value': ['HP:0012164',
#      'NCIT:C86048',
#      'UMLS:C0232766',
#      'MEDDRA:10003547',
#      'MEDDRA:10057580',
#      'SNOMEDCT:32838008',
#      'HP:0012164',
#      'NCIT:C86048',
#      'UMLS:C0232766',
#      'MEDDRA:10003547',
#      'MEDDRA:10057580',
#      'SNOMEDCT:32838008',
#      'HP:0012164',
#      'NCIT:C86048',
#      'UMLS:C0232766',
#      'MEDDRA:10003547',
#      'MEDDRA:10057580',
#      'SNOMEDCT:32838008',
#      'HP:0012164',
#      'NCIT:C86048',
#      'UMLS:C0232766',
#      'MEDDRA:10003547',
#      'MEDDRA:10057580',
#      'SNOMEDCT:32838008',
#      'HP:0012164',
#      'NCIT:C86048',
#      'UMLS:C0232766',
#      'MEDDRA:10003547',
#      'MEDDRA:10057580',
#      'SNOMEDCT:32838008'],
#     'value_type_id': 'metatype:uriorcurie',
#     'original_attribute_name': 'equivalent_identifiers',
#     'value_url': None,
#     'attribute_source': None,
#     'description': None,
#     'attributes': None}]})

# %% [markdown]
# Information returned for the each Edge includes the edge ID (key), the subject's concept ID, the object's concept ID, the edge's predicate, any qualifiers, and attributes.  Note that each entry under the `edges` level is itemized in dictionary format and not lists.  The content for one Edge is shown below.

# %%
next(iter( response.json()['message']['knowledge_graph']['edges'].items() ))
# Out:
# ('71600575',
#  {'subject': 'PUBCHEM.COMPOUND:644073',
#   'object': 'NCBIGene:4988',
#   'predicate': 'biolink:affects',
#   'qualifiers': None,
#   'attributes': [{'attribute_type_id': 'biolink:qualified_predicate',
#     'value': 'biolink:causes',
#     'value_type_id': 'EDAM:data_0006',
#     'original_attribute_name': 'qualified_predicate',
#     'value_url': None,
#     'attribute_source': None,
#     'description': None,
#     'attributes': None},
#    {'attribute_type_id': 'biolink:object_direction_qualifier',
#     'value': 'increased',
#     'value_type_id': 'EDAM:data_0006',
#     'original_attribute_name': 'object_direction_qualifier',
#     'value_url': None,
#     'attribute_source': None,
#     'description': None,
#     'attributes': None},
#    {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#     'value': ['infores:pharos'],
#     'value_type_id': 'biolink:InformationResource',
#     'original_attribute_name': 'biolink:aggregator_knowledge_source',
#     'value_url': None,
#     'attribute_source': 'infores:automat-robokop',
#     'description': None,
#     'attributes': None},
#    {'attribute_type_id': 'biolink:primary_knowledge_source',
#     'value': ['infores:pharos'],
#     'value_type_id': 'biolink:InformationResource',
#     'original_attribute_name': 'biolink:primary_knowledge_source',
#     'value_url': None,
#     'attribute_source': 'infores:automat-robokop',
#     'description': None,
#     'attributes': None},
#    {'attribute_type_id': 'biolink:Attribute',
#     'value': 8.29,
#     'value_type_id': 'EDAM:data_0006',
#     'original_attribute_name': 'affinity',
#     'value_url': None,
#     'attribute_source': None,
#     'description': None,
#     'attributes': None},
#    {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#     'value': ['infores:automat-robokop'],
#     'value_type_id': 'biolink:InformationResource',
#     'original_attribute_name': 'biolink:aggregator_knowledge_source',
#     'value_url': None,
#     'attribute_source': 'infores:automat-robokop',
#     'description': None,
#     'attributes': None},
#    {'attribute_type_id': 'biolink:Attribute',
#     'value': 'Ki',
#     'value_type_id': 'EDAM:data_0006',
#     'original_attribute_name': 'affinity_parameter',
#     'value_url': None,
#     'attribute_source': None,
#     'description': None,
#     'attributes': None},
#    {'attribute_type_id': 'biolink:object_aspect_qualifier',
#     'value': 'activity',
#     'value_type_id': 'EDAM:data_0006',
#     'original_attribute_name': 'object_aspect_qualifier',
#     'value_url': None,
#     'attribute_source': None,
#     'description': None,
#     'attributes': None}]})

# %% [markdown]
# Since the edge and node contents are returned as CURIES (Compact URIs) instead of labels, a sample workflow was written to show how to use the above edge information and the Node Normalizer tool to convert results into a human readble form.  This workflow does the following steps:
# - combine edge_binding IDs and convert edge IDs to labels for each result
# - use Node Normalizer to convert node IDs to labels
# - write the output dictionary as a CSV

# %%
edges = response.json()['message']['results'][0]['edge_bindings'].keys()
nodes = response.json()['message']['results'][0]['node_bindings'].keys()
edges_nodes = sorted(edges|nodes)

edges_nodes_keys = [s for s in edges_nodes if not s.startswith('s')]
print(edges_nodes_keys)

# Initializing a base dictionary containing edge and node IDs from message results
base_dict = {}
for key in edges_nodes_keys:
    base_dict[key] = {}
print(base_dict)
# Out:
# ['e00', 'e01', 'n00', 'n01', 'n02']
# {'e00': {}, 'e01': {}, 'n00': {}, 'n01': {}, 'n02': {}}

# %%
# Illustrating the structure of each pathway result from the message component
pp.pprint(response.json()['message']['results'][0])
# Out:
# {    'edge_bindings': {    'e00': [    {'attributes': None, 'id': '29599157'},
#                                        {'attributes': None, 'id': '117577598'},
#                                        {'attributes': None, 'id': '8921721'}],
#                            'e01': [{'attributes': None, 'id': '134555909'}]},
#      'node_bindings': {    'n00': [    {    'attributes': None,
#                                             'id': 'PUBCHEM.COMPOUND:644073',
#                                             'qnode_id': 'PUBCHEM.COMPOUND:644073',
#                                             'query_id': None}],
#                            'n01': [    {    'attributes': None,
#                                             'id': 'NCBIGene:1565',
#                                             'query_id': None}],
#                            'n02': [    {    'attributes': None,
#                                             'id': 'HP:0002174',
#                                             'qnode_id': 'HP:0001337',
#                                             'query_id': None}]},
#      'score': None}

# %%
# - populate base_dict with entries from response.json()['message']['results']
i = 0
for entry in response.json()['message']['results']:
    for edge_id in edges:
        base_dict[edge_id][i] = entry['edge_bindings'][edge_id][0]['id']
    for node_id in nodes:
        base_dict[node_id][i] = entry['node_bindings'][node_id][0]['id']
    i = i + 1
        
pp.pprint(base_dict)
# Out:
# {    'e00': {    0: '29599157',
#                  1: '29599157',
#                  2: '54570655',
#                  3: '29599157',
#                  4: '29599157',
#                  5: '29599157',
#                  6: '29599157'},
#      'e01': {    0: '134555909',
#                  1: '94775101',
#                  2: '124404541',
#                  3: '36779780',
#                  4: '14946110',
#                  5: '101782561',
#                  6: '40925070'},
#      'n00': {    0: 'PUBCHEM.COMPOUND:644073',
#                  1: 'PUBCHEM.COMPOUND:644073',
#                  2: 'PUBCHEM.COMPOUND:644073',
#                  3: 'PUBCHEM.COMPOUND:644073',
#                  4: 'PUBCHEM.COMPOUND:644073',
#                  5: 'PUBCHEM.COMPOUND:644073',
#                  6: 'PUBCHEM.COMPOUND:644073'},
#      'n01': {    0: 'NCBIGene:1565',
#                  1: 'NCBIGene:1565',
#                  2: 'NCBIGene:4988',
#                  3: 'NCBIGene:1565',
#                  4: 'NCBIGene:1565',
#                  5: 'NCBIGene:1565',
#                  6: 'NCBIGene:1565'},
#      'n02': {    0: 'HP:0002174',
#                  1: 'HP:0002345',
#                  2: 'HP:0012164',
#                  3: 'HP:0200085',
#                  4: 'HP:0001337',
#                  5: 'HP:0025387',
#                  6: 'HP:0002322'}}

# %%
import copy
output_dict = copy.deepcopy(base_dict)
edge_list = [x for x in output_dict.keys() if 'e' in x]
#print(edge_list)

# - convert and combine edge_binding IDs for each result
for edge_id in edge_list:
    for edge_index, edge_number in output_dict[edge_id].items():
        # Getting the predicate/label using the edge_binding ID from the knowledge graph
        output_dict[edge_id][edge_index] = response.json()['message']['knowledge_graph']['edges'][edge_number]['predicate']

pp.pprint(output_dict)
# Out:
# {    'e00': {    0: 'biolink:directly_physically_interacts_with',
#                  1: 'biolink:directly_physically_interacts_with',
#                  2: 'biolink:affects',
#                  3: 'biolink:directly_physically_interacts_with',
#                  4: 'biolink:directly_physically_interacts_with',
#                  5: 'biolink:directly_physically_interacts_with',
#                  6: 'biolink:directly_physically_interacts_with'},
#      'e01': {    0: 'biolink:genetic_association',
#                  1: 'biolink:genetic_association',
#                  2: 'biolink:genetic_association',
#                  3: 'biolink:genetic_association',
#                  4: 'biolink:genetic_association',
#                  5: 'biolink:genetic_association',
#                  6: 'biolink:genetic_association'},
#      'n00': {    0: 'PUBCHEM.COMPOUND:644073',
#                  1: 'PUBCHEM.COMPOUND:644073',
#                  2: 'PUBCHEM.COMPOUND:644073',
#                  3: 'PUBCHEM.COMPOUND:644073',
#                  4: 'PUBCHEM.COMPOUND:644073',
#                  5: 'PUBCHEM.COMPOUND:644073',
#                  6: 'PUBCHEM.COMPOUND:644073'},
#      'n01': {    0: 'NCBIGene:1565',
#                  1: 'NCBIGene:1565',
#                  2: 'NCBIGene:4988',
#                  3: 'NCBIGene:1565',
#                  4: 'NCBIGene:1565',
#                  5: 'NCBIGene:1565',
#                  6: 'NCBIGene:1565'},
#      'n02': {    0: 'HP:0002174',
#                  1: 'HP:0002345',
#                  2: 'HP:0012164',
#                  3: 'HP:0200085',
#                  4: 'HP:0001337',
#                  5: 'HP:0025387',
#                  6: 'HP:0002322'}}

# %%
# - using the Node Normalizer to convert Node IDs to labels
node_list = [x for x in output_dict.keys() if 'n' in x]

curies_list = []
for node_id in node_list:
    for node_index, node_value in output_dict[node_id].items():
        if node_value not in curies_list:
            curies_list.append(node_value)

print(curies_list)
    
nn_query = {
  "curies": curies_list,
  "conflate": True
}
results = requests.post('https://nodenormalization-sri.renci.org/get_normalized_nodes',json=nn_query)
results_dict = results.json()
pp.pprint(json.dumps(results_dict))
# Out:
# ['PUBCHEM.COMPOUND:644073', 'NCBIGene:1565', 'NCBIGene:4988', 'HP:0002174', 'HP:0002345', 'HP:0012164', 'HP:0200085', 'HP:0001337', 'HP:0025387', 'HP:0002322']
# ('{"PUBCHEM.COMPOUND:644073": {"id": {"identifier": "PUBCHEM.COMPOUND:644073", '
#  '"label": "Buprenorphine"}, "equivalent_identifiers": [{"identifier": '
#  '"PUBCHEM.COMPOUND:644073", "label": "Buprenorphine"}, {"identifier": '
#  '"CHEMBL.COMPOUND:CHEMBL560511", "label": "CHEMBL560511"}, {"identifier": '
#  '"UNII:40D3SCR4GZ", "label": "BUPRENORPHINE"}, {"identifier": "CHEBI:3216", '
#  '"label": "buprenorphine"}, {"identifier": "DRUGBANK:DB00921"}, '
#  '{"identifier": "MESH:D002047", "label": "Buprenorphine"}, {"identifier": '
#  '"CAS:52485-79-7"}, {"identifier": "DrugCentral:434", "label": '
#  '"buprenorphine"}, {"identifier": "GTOPDB:1670", "label": "buprenorphine"}, '
#  '{"identifier": "HMDB:HMDB0015057", "label": "Buprenorphine"}, {"identifier": '
#  '"KEGG.COMPOUND:C08007", "label": "Buprenorphine"}, {"identifier": '
#  '"INCHIKEY:RMRJXGBAOAMLHD-IHFGGWKQSA-N"}, {"identifier": "UMLS:C0006405", '
#  '"label": "buprenorphine"}], "type": ["biolink:SmallMolecule", '
#  '"biolink:MolecularEntity", "biolink:ChemicalEntity", '
#  '"biolink:PhysicalEssence", "biolink:ChemicalOrDrugOrTreatment", '
#  '"biolink:ChemicalEntityOrGeneOrGeneProduct", '
#  '"biolink:ChemicalEntityOrProteinOrPolypeptide", "biolink:NamedThing", '
#  '"biolink:Entity", "biolink:PhysicalEssenceOrOccurrent"], '
#  '"information_content": 100.0}, "NCBIGene:1565": {"id": {"identifier": '
#  '"NCBIGene:1565", "label": "CYP2D6"}, "equivalent_identifiers": '
#  '[{"identifier": "NCBIGene:1565", "label": "CYP2D6"}, {"identifier": '
#  '"ENSEMBL:ENSG00000100197"}, {"identifier": "HGNC:2625", "label": "CYP2D6"}, '
#  '{"identifier": "OMIM:124030"}, {"identifier": "UMLS:C1332830", "label": '
#  '"CYP2D6 gene"}, {"identifier": "UniProtKB:C1ID52", "label": "C1ID52_HUMAN '
#  'Cytochrome P450 (trembl)"}, {"identifier": "UniProtKB:P10635", "label": '
#  '"CP2D6_HUMAN Cytochrome P450 2D6 (sprot)"}, {"identifier": "PR:P10635", '
#  '"label": "cytochrome P450 2D6 (human)"}, {"identifier": '
#  '"ENSEMBL:ENSP00000483677"}, {"identifier": "ENSEMBL:ENSP00000483677.1"}, '
#  '{"identifier": "UMLS:C3887685", "label": "Cytochrome P450 2D6, human"}, '
#  '{"identifier": "UniProtKB:Q5Y7H2", "label": "Q5Y7H2_HUMAN CYP2D variant '
#  '(Fragment) (trembl)"}], "type": ["biolink:Gene", '
#  '"biolink:GeneOrGeneProduct", "biolink:GenomicEntity", '
#  '"biolink:ChemicalEntityOrGeneOrGeneProduct", "biolink:PhysicalEssence", '
#  '"biolink:OntologyClass", "biolink:BiologicalEntity", "biolink:NamedThing", '
#  '"biolink:Entity", "biolink:PhysicalEssenceOrOccurrent", '
#  '"biolink:ThingWithTaxon", "biolink:MacromolecularMachineMixin", '
#  '"biolink:Protein", "biolink:GeneProductMixin", "biolink:Polypeptide", '
#  '"biolink:ChemicalEntityOrProteinOrPolypeptide"], "information_content": '
#  '100.0}, "NCBIGene:4988": {"id": {"identifier": "NCBIGene:4988", "label": '
#  '"OPRM1"}, "equivalent_identifiers": [{"identifier": "NCBIGene:4988", '
#  '"label": "OPRM1"}, {"identifier": "ENSEMBL:ENSG00000112038"}, {"identifier": '
#  '"HGNC:8156", "label": "OPRM1"}, {"identifier": "OMIM:600018"}, '
#  '{"identifier": "UMLS:C1417965", "label": "OPRM1 gene"}, {"identifier": '
#  '"UniProtKB:B8K2Q5", "label": "B8K2Q5_HUMAN Mu opioid receptor splice variant '
#  'MOR-1H (Fragment) (trembl)"}, {"identifier": "UniProtKB:G8XRH4", "label": '
#  '"G8XRH4_HUMAN Mu opioid receptor splice variant hMOR-1S (trembl)"}, '
#  '{"identifier": "UniProtKB:G8XRH5", "label": "G8XRH5_HUMAN Mu-type opioid '
#  'receptor (trembl)"}, {"identifier": "UniProtKB:L0E130", "label": '
#  '"L0E130_HUMAN Mu-type opioid receptor (trembl)"}, {"identifier": '
#  '"ENSEMBL:ENSP00000353598"}, {"identifier": "ENSEMBL:ENSP00000353598.5"}, '
#  '{"identifier": "UniProtKB:P35372", "label": "OPRM_HUMAN Mu-type opioid '
#  'receptor (sprot)"}, {"identifier": "PR:P35372", "label": "mu-type opioid '
#  'receptor (human)"}, {"identifier": "UMLS:C1436808", "label": "OPRM1 protein, '
#  'human"}], "type": ["biolink:Gene", "biolink:GeneOrGeneProduct", '
#  '"biolink:GenomicEntity", "biolink:ChemicalEntityOrGeneOrGeneProduct", '
#  '"biolink:PhysicalEssence", "biolink:OntologyClass", '
#  '"biolink:BiologicalEntity", "biolink:NamedThing", "biolink:Entity", '
#  '"biolink:PhysicalEssenceOrOccurrent", "biolink:ThingWithTaxon", '
#  '"biolink:MacromolecularMachineMixin", "biolink:Protein", '
#  '"biolink:GeneProductMixin", "biolink:Polypeptide", '
#  '"biolink:ChemicalEntityOrProteinOrPolypeptide"], "information_content": '
#  '100.0}, "HP:0002174": {"id": {"identifier": "HP:0002174", "label": "Postural '
#  'tremor"}, "equivalent_identifiers": [{"identifier": "HP:0002174", "label": '
#  '"Postural tremor"}, {"identifier": "UMLS:C0234378", "label": "Static '
#  'Tremor"}, {"identifier": "MEDDRA:10073211"}, {"identifier": '
#  '"SNOMEDCT:56610005"}], "type": ["biolink:PhenotypicFeature", '
#  '"biolink:DiseaseOrPhenotypicFeature", "biolink:ThingWithTaxon", '
#  '"biolink:BiologicalEntity", "biolink:NamedThing", "biolink:Entity"], '
#  '"information_content": 94.9}, "HP:0002345": {"id": {"identifier": '
#  '"HP:0002345", "label": "Action tremor"}, "equivalent_identifiers": '
#  '[{"identifier": "HP:0002345", "label": "Action tremor"}, {"identifier": '
#  '"NCIT:C183162", "label": "Action Tremor"}, {"identifier": "UMLS:C0234376", '
#  '"label": "Action Tremor"}, {"identifier": "UMLS:C4020853", "label": "Ataxic '
#  'tremor"}, {"identifier": "MEDDRA:10072413"}, {"identifier": '
#  '"SNOMEDCT:30721006"}], "type": ["biolink:PhenotypicFeature", '
#  '"biolink:DiseaseOrPhenotypicFeature", "biolink:ThingWithTaxon", '
#  '"biolink:BiologicalEntity", "biolink:NamedThing", "biolink:Entity"], '
#  '"information_content": 83.1}, "HP:0012164": {"id": {"identifier": '
#  '"HP:0012164", "label": "Asterixis"}, "equivalent_identifiers": '
#  '[{"identifier": "HP:0012164", "label": "Asterixis"}, {"identifier": '
#  '"NCIT:C86048", "label": "Asterixis"}, {"identifier": "UMLS:C0232766", '
#  '"label": "Asterixis"}, {"identifier": "MEDDRA:10003547"}, {"identifier": '
#  '"MEDDRA:10057580"}, {"identifier": "SNOMEDCT:32838008"}], "type": '
#  '["biolink:PhenotypicFeature", "biolink:DiseaseOrPhenotypicFeature", '
#  '"biolink:ThingWithTaxon", "biolink:BiologicalEntity", "biolink:NamedThing", '
#  '"biolink:Entity"], "information_content": 100.0}, "HP:0200085": {"id": '
#  '{"identifier": "HP:0200085", "label": "Limb tremor"}, '
#  '"equivalent_identifiers": [{"identifier": "HP:0200085", "label": "Limb '
#  'tremor"}, {"identifier": "UMLS:C0235081", "label": "Tremor, Limb"}, '
#  '{"identifier": "MEDDRA:10044572"}], "type": ["biolink:PhenotypicFeature", '
#  '"biolink:DiseaseOrPhenotypicFeature", "biolink:ThingWithTaxon", '
#  '"biolink:BiologicalEntity", "biolink:NamedThing", "biolink:Entity"], '
#  '"information_content": 94.9}, "HP:0001337": {"id": {"identifier": '
#  '"HP:0001337", "label": "Tremor"}, "equivalent_identifiers": [{"identifier": '
#  '"HP:0001337", "label": "Tremor"}, {"identifier": "NCIT:C38038", "label": '
#  '"Tremor"}, {"identifier": "UMLS:C0040822", "label": "Tremor"}, '
#  '{"identifier": "UMLS:C0234369", "label": "Trembling"}, {"identifier": '
#  '"UMLS:C1527384", "label": "Involuntary Quiver"}, {"identifier": '
#  '"MEDDRA:10040528"}, {"identifier": "MEDDRA:10044562"}, {"identifier": '
#  '"MEDDRA:10044563"}, {"identifier": "MEDDRA:10044565"}, {"identifier": '
#  '"SNOMEDCT:26079004"}, {"identifier": "SNOMEDCT:267079009"}, {"identifier": '
#  '"MESH:D014202", "label": "Tremor"}], "type": ["biolink:PhenotypicFeature", '
#  '"biolink:DiseaseOrPhenotypicFeature", "biolink:ThingWithTaxon", '
#  '"biolink:BiologicalEntity", "biolink:NamedThing", "biolink:Entity"], '
#  '"information_content": 78.0}, "HP:0025387": {"id": {"identifier": '
#  '"HP:0025387", "label": "Pill-rolling tremor"}, "equivalent_identifiers": '
#  '[{"identifier": "HP:0025387", "label": "Pill-rolling tremor"}, '
#  '{"identifier": "UMLS:C0751564", "label": "Pill Rolling Tremor"}, '
#  '{"identifier": "MEDDRA:10056445"}, {"identifier": "SNOMEDCT:112108005"}], '
#  '"type": ["biolink:PhenotypicFeature", "biolink:DiseaseOrPhenotypicFeature", '
#  '"biolink:ThingWithTaxon", "biolink:BiologicalEntity", "biolink:NamedThing", '
#  '"biolink:Entity"], "information_content": 100.0}, "HP:0002322": {"id": '
#  '{"identifier": "HP:0002322", "label": "Resting tremor"}, '
#  '"equivalent_identifiers": [{"identifier": "HP:0002322", "label": "Resting '
#  'tremor"}, {"identifier": "NCIT:C182454", "label": "Resting Tremor"}, '
#  '{"identifier": "UMLS:C0234379", "label": "Resting Tremor"}, {"identifier": '
#  '"UMLS:C0586392", "label": "Parkinsonian tremor"}, {"identifier": '
#  '"MEDDRA:10071390"}, {"identifier": "SNOMEDCT:25082004"}, {"identifier": '
#  '"SNOMEDCT:308909003"}], "type": ["biolink:PhenotypicFeature", '
#  '"biolink:DiseaseOrPhenotypicFeature", "biolink:ThingWithTaxon", '
#  '"biolink:BiologicalEntity", "biolink:NamedThing", "biolink:Entity"], '
#  '"information_content": 94.9}}')

# %%
print(results_dict.keys())
for node_id in node_list:
    for node_index, node_value in output_dict[node_id].items():
        output_dict[node_id][node_index] = results_dict[node_value]['id']['label']
        
pp.pprint(output_dict)
# Out:
# dict_keys(['PUBCHEM.COMPOUND:644073', 'NCBIGene:1565', 'NCBIGene:4988', 'HP:0002174', 'HP:0002345', 'HP:0012164', 'HP:0200085', 'HP:0001337', 'HP:0025387', 'HP:0002322'])
# {    'e00': {    0: 'biolink:directly_physically_interacts_with',
#                  1: 'biolink:directly_physically_interacts_with',
#                  2: 'biolink:affects',
#                  3: 'biolink:directly_physically_interacts_with',
#                  4: 'biolink:directly_physically_interacts_with',
#                  5: 'biolink:directly_physically_interacts_with',
#                  6: 'biolink:directly_physically_interacts_with'},
#      'e01': {    0: 'biolink:genetic_association',
#                  1: 'biolink:genetic_association',
#                  2: 'biolink:genetic_association',
#                  3: 'biolink:genetic_association',
#                  4: 'biolink:genetic_association',
#                  5: 'biolink:genetic_association',
#                  6: 'biolink:genetic_association'},
#      'n00': {    0: 'Buprenorphine',
#                  1: 'Buprenorphine',
#                  2: 'Buprenorphine',
#                  3: 'Buprenorphine',
#                  4: 'Buprenorphine',
#                  5: 'Buprenorphine',
#                  6: 'Buprenorphine'},
#      'n01': {    0: 'CYP2D6',
#                  1: 'CYP2D6',
#                  2: 'OPRM1',
#                  3: 'CYP2D6',
#                  4: 'CYP2D6',
#                  5: 'CYP2D6',
#                  6: 'CYP2D6'},
#      'n02': {    0: 'Postural tremor',
#                  1: 'Action tremor',
#                  2: 'Asterixis',
#                  3: 'Limb tremor',
#                  4: 'Tremor',
#                  5: 'Pill-rolling tremor',
#                  6: 'Resting tremor'}}

# %%
import pandas as pd

# Convert JSON String to CSV File
# Read json from String
json_str = json.dumps(output_dict, indent=4)
df = pd.read_json(json_str)
df.to_csv('query_output_dnw.csv')

# %% [markdown]
# A separate name resolver is shown here.  The name-resolver: https://name-resolution-sri.renci.org/docs has a lookup function that can take a string and return potential identifiers.  Here, we look up the string "tremor"

# %%
search_string = 'tremor'
results = requests.post(f'https://name-resolution-sri.renci.org/lookup?string={search_string}&offset=0&limit=10')

# %%
print(json.dumps(results.json(),indent=4))
# Out:
# {
#     "HP:0001337": [
#         "Tremor",
#         "tremor",
#         "TREMOR",
#         "TREMORS",
#         "Tremors",
#         "tremors",
#         "d tremors",
#         "Tremor NOS",
#         "Tremor, NOS",
#         "Has a tremor",
#         "A46-A47 TREMORS",
#         "Shaking/Tremors",
#         "Tremor (finding)",
#         "tremors as symptom",
#         "tremor (diagnosis)",
#         "Tremor, unspecified",
#         "tremor (physical finding)",
#         "motor exam involuntary movements tremor trembles",
#         "involuntary shaking or trembling movements (tremor)",
#         "shake",
#         "shakes",
#         "quiver",
#         "Shakes",
#         "tremble",
#         "Shaking",
#         "shaking",
#         "Tremble",
#         "quivers",
#         "SHAKING",
#         "Trembled",
#         "Quivered",
#         "trembles",
#         "Trembles",
#         "TREMBLING",
#         "TREMULOUS",
#         "Trembling",
#         "trembling",
#         "Quivering",
#         "quivering",
#         "tremulous",
#         "The shakes",
#         "the shakes",
#         "Shaking all over",
#         "Trembles (finding)",
#         "Involuntary quiver",
#         "Involuntary Quiver",
#         "Involuntary Quivers",
#         "Quiver, Involuntary",
#         "Involuntary shaking",
#         "Quivers, Involuntary",
#         "Involuntary trembling",
#         "trembles (physical finding)",
#         "involuntary shaking or trembling movements",
#         "involuntary shaking or trembling movements (symptom)"
#     ],
#     "NCIT:C55596": [
#         "Tremor",
#         "Tremor, CTCAE_3",
#         "Tremor, CTCAE 3.0"
#     ],
#     "NCIT:C146780": [
#         "Tremor",
#         "Tremor, CTCAE_5",
#         "Tremor, CTCAE 5.0"
#     ],
#     "PUBCHEM.COMPOUND:5534": [
#         "Tremorine",
#         "TREMORINE",
#         "CHEMBL1483237",
#         "1-[4-(1-pyrrolidinyl)but-2-ynyl]pyrrolidine"
#     ],
#     "UMLS:C1836697": [
#         "No tremor"
#     ],
#     "PUBCHEM.COMPOUND:337313": [
#         "tremortin",
#         "Tremortin A"
#     ],
#     "HMDB:HMDB0242736": [
#         "Tremortin",
#         "Tremortin a",
#         "Tremortin b",
#         "Penitrems",
#         "penitrem A",
#         "Penitrem b",
#         "Penitrem e",
#         "Penitrem D"
#     ],
#     "UMLS:C0240081": [
#         "JAW TREMOR",
#         "jaw tremor",
#         "jaw tremors"
#     ],
#     "HP:0032006": [
#         "Lip tremor",
#         "tremor lip",
#         "lip tremor",
#         "LIP TREMOR",
#         "lip tremors"
#     ],
#     "UMLS:C1961111": [
#         "Tremor NEC",
#         "Tremor NEC in ICD9CM_2014",
#         "Essential and other specified forms of tremor"
#     ]
# }

# %% [markdown]
# The node normalizer (https://nodenormalization-sri.renci.org/docs) takes CURIES and returns all other CURIES that are synonymous with the input. It also returns labels for the node, the biolink classes of the node, and often the information content of the node.

# %%
nn_query = {
  "curies": [
    "NCBIGene:4988",
  ],
  "conflate": True
}
results = requests.post('https://nodenormalization-sri.renci.org/get_normalized_nodes',json=nn_query)

# %%
print(json.dumps(results.json(),indent=4))
# Out:
# {
#     "NCBIGene:4988": {
#         "id": {
#             "identifier": "NCBIGene:4988",
#             "label": "OPRM1"
#         },
#         "equivalent_identifiers": [
#             {
#                 "identifier": "NCBIGene:4988",
#                 "label": "OPRM1"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSG00000112038"
#             },
#             {
#                 "identifier": "HGNC:8156",
#                 "label": "OPRM1"
#             },
#             {
#                 "identifier": "OMIM:600018"
#             },
#             {
#                 "identifier": "UMLS:C1417965",
#                 "label": "OPRM1 gene"
#             },
#             {
#                 "identifier": "UniProtKB:B8K2Q5",
#                 "label": "B8K2Q5_HUMAN Mu opioid receptor splice variant MOR-1H (Fragment) (trembl)"
#             },
#             {
#                 "identifier": "UniProtKB:G8XRH4",
#                 "label": "G8XRH4_HUMAN Mu opioid receptor splice variant hMOR-1S (trembl)"
#             },
#             {
#                 "identifier": "UniProtKB:G8XRH5",
#                 "label": "G8XRH5_HUMAN Mu-type opioid receptor (trembl)"
#             },
#             {
#                 "identifier": "UniProtKB:L0E130",
#                 "label": "L0E130_HUMAN Mu-type opioid receptor (trembl)"
#             },
#             {
#                 "identifier": "ENSEMBL:ENSP00000353598.5"
#             },
#             {
#                 "identifier": "UniProtKB:P35372",
#                 "label": "OPRM_HUMAN Mu-type opioid receptor (sprot)"
#             },
#             {
#                 "identifier": "PR:P35372",
#                 "label": "mu-type opioid receptor (human)"
#             },
#             {
#                 "identifier": "UMLS:C1436808",
#                 "label": "OPRM1 protein, human"
#             }
#         ],
#         "type": [
#             "biolink:Gene",
#             "biolink:GeneOrGeneProduct",
#             "biolink:GenomicEntity",
#             "biolink:ChemicalEntityOrGeneOrGeneProduct",
#             "biolink:PhysicalEssence",
#             "biolink:OntologyClass",
#             "biolink:BiologicalEntity",
#             "biolink:NamedThing",
#             "biolink:Entity",
#             "biolink:PhysicalEssenceOrOccurrent",
#             "biolink:ThingWithTaxon",
#             "biolink:MacromolecularMachineMixin",
#             "biolink:Protein",
#             "biolink:GeneProductMixin",
#             "biolink:Polypeptide",
#             "biolink:ChemicalEntityOrProteinOrPolypeptide"
#         ],
#         "information_content": 100.0
#     }
# }

# %% [markdown]
# The results above are just database matches, there are no scores or other additions.  You can instead send the TRAPI to the robokop application using Aragorn (rather than just to the graph)

# %%
ara_robokop_submit_url = "https://aragorn.renci.org/robokop/query"
response = requests.post(ara_robokop_submit_url,json=query)

# %%
response.status_code
# Out:
# 200

# %%
len(response.json()['message']['results'])
# Out:
# 7

# %%
pp.pprint(response.json()['message']['results'])
# Out:
# [    {    'edge_bindings': {    'e00': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:ctd',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '117577598'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:ctd',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '8921721'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:hetio',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '29599157'}],
#                                 'e01': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'CTD',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '14946110'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'DisGeNET',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '106330495'}],
#                                 's2': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.01969688375322365,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': '6a99afda-1fab-4e52-8640-6cc4f0146ae3'}],
#                                 's5': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.0237651554049918,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': 'a5b2f731-5359-4233-9b09-f2143ac8b7a3'}],
#                                 's6': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.031046980543924407,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': '59abd715-dcb8-4da3-96b4-0452f395811a'}]},
#           'node_bindings': {    'n00': [    {    'attributes': None,
#                                                  'id': 'PUBCHEM.COMPOUND:644073',
#                                                  'qnode_id': 'PUBCHEM.COMPOUND:644073',
#                                                  'query_id': None}],
#                                 'n01': [    {    'attributes': None,
#                                                  'id': 'NCBIGene:1565',
#                                                  'query_id': None}],
#                                 'n02': [    {    'attributes': None,
#                                                  'id': 'HP:0001337',
#                                                  'qnode_id': 'HP:0001337',
#                                                  'query_id': None}]},
#           'score': 0.17813345082933513},
#      {    'edge_bindings': {    'e00': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:drugcentral',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '54570655'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:pharos',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.4999999999999998,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '86663992'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:gtopdb',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.4999999999999998,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '17587427'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:pharos',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '71600575'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:hetio',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '53347208'}],
#                                 'e01': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'DisGeNET',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '124404541'}],
#                                 's8': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.0006165611453281539,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': 'f99f2d83-20b4-485e-af2e-2fcf23e7ef0b'}],
#                                 's9': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.014200987810474519,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': '966e2e9b-a7b6-4e64-983c-3da1f9beb863'}]},
#           'node_bindings': {    'n00': [    {    'attributes': None,
#                                                  'id': 'PUBCHEM.COMPOUND:644073',
#                                                  'qnode_id': 'PUBCHEM.COMPOUND:644073',
#                                                  'query_id': None}],
#                                 'n01': [    {    'attributes': None,
#                                                  'id': 'NCBIGene:4988',
#                                                  'query_id': None}],
#                                 'n02': [    {    'attributes': None,
#                                                  'id': 'HP:0012164',
#                                                  'qnode_id': 'HP:0001337',
#                                                  'query_id': None}]},
#           'score': 0.11703906793268538},
#      {    'edge_bindings': {    'e00': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:ctd',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '117577598'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:ctd',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '8921721'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:hetio',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '29599157'}],
#                                 'e01': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'DisGeNET',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '40925070'}],
#                                 's2': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.01969688375322365,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': '6a99afda-1fab-4e52-8640-6cc4f0146ae3'}],
#                                 's3': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.0017541448260329773,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': '646e3f61-6bdc-4102-8c1e-3cf83cc05a6a'}],
#                                 's4': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.001048980791540366,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': 'bea54dc4-0d27-4bca-910d-ded0541f3f04'}]},
#           'node_bindings': {    'n00': [    {    'attributes': None,
#                                                  'id': 'PUBCHEM.COMPOUND:644073',
#                                                  'qnode_id': 'PUBCHEM.COMPOUND:644073',
#                                                  'query_id': None}],
#                                 'n01': [    {    'attributes': None,
#                                                  'id': 'NCBIGene:1565',
#                                                  'query_id': None}],
#                                 'n02': [    {    'attributes': None,
#                                                  'id': 'HP:0002322',
#                                                  'qnode_id': 'HP:0001337',
#                                                  'query_id': None}]},
#           'score': 0.1020104827729211},
#      {    'edge_bindings': {    'e00': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:ctd',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '117577598'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:ctd',
# ...
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:hetio',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '29599157'}],
#                                 'e01': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'DisGeNET',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '101782561'}],
#                                 's2': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.01969688375322365,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': '6a99afda-1fab-4e52-8640-6cc4f0146ae3'}]},
#           'node_bindings': {    'n00': [    {    'attributes': None,
#                                                  'id': 'PUBCHEM.COMPOUND:644073',
#                                                  'qnode_id': 'PUBCHEM.COMPOUND:644073',
#                                                  'query_id': None}],
#                                 'n01': [    {    'attributes': None,
#                                                  'id': 'NCBIGene:1565',
#                                                  'query_id': None}],
#                                 'n02': [    {    'attributes': None,
#                                                  'id': 'HP:0025387',
#                                                  'qnode_id': 'HP:0001337',
#                                                  'query_id': None}]},
#           'score': 0.1010853670864079},
#      {    'edge_bindings': {    'e00': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:ctd',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '117577598'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:ctd',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '8921721'},
#                                             {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'infores:hetio',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '29599157'}],
#                                 'e01': [    {    'attributes': [    {    'attribute_source': None,
#                                                                          'attribute_type_id': 'biolink:has_numeric_value',
#                                                                          'attributes': [    {    'attribute_source': None,
#                                                                                                  'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                  'attributes': None,
#                                                                                                  'description': None,
#                                                                                                  'original_attribute_name': 'aragorn_weight_source',
#                                                                                                  'value': 'DisGeNET',
#                                                                                                  'value_type_id': 'biolink:InformationResource',
#                                                                                                  'value_url': None}],
#                                                                          'description': None,
#                                                                          'original_attribute_name': 'weight',
#                                                                          'value': 0.2679491924311228,
#                                                                          'value_type_id': 'EDAM:data_1669',
#                                                                          'value_url': None}],
#                                                  'id': '36779780'}],
#                                 's2': [    {    'attributes': [    {    'attribute_source': None,
#                                                                         'attribute_type_id': 'biolink:has_numeric_value',
#                                                                         'attributes': [    {    'attribute_source': None,
#                                                                                                 'attribute_type_id': 'biolink:has_qualitative_value',
#                                                                                                 'attributes': None,
#                                                                                                 'description': None,
#                                                                                                 'original_attribute_name': 'aragorn_weight_source',
#                                                                                                 'value': 'infores:aragorn-ranker-ara',
#                                                                                                 'value_type_id': 'biolink:InformationResource',
#                                                                                                 'value_url': None}],
#                                                                         'description': None,
#                                                                         'original_attribute_name': 'weight',
#                                                                         'value': 0.01969688375322365,
#                                                                         'value_type_id': 'EDAM:data_1669',
#                                                                         'value_url': None}],
#                                                 'id': '6a99afda-1fab-4e52-8640-6cc4f0146ae3'}]},
#           'node_bindings': {    'n00': [    {    'attributes': None,
#                                                  'id': 'PUBCHEM.COMPOUND:644073',
#                                                  'qnode_id': 'PUBCHEM.COMPOUND:644073',
#                                                  'query_id': None}],
#                                 'n01': [    {    'attributes': None,
#                                                  'id': 'NCBIGene:1565',
#                                                  'query_id': None}],
#                                 'n02': [    {    'attributes': None,
#                                                  'id': 'HP:0200085',
#                                                  'qnode_id': 'HP:0001337',
#                                                  'query_id': None}]},
#           'score': 0.1010853670864079}]

# %%
for result in response.json()['message']['results']:
    print(result['score'])
# Out:
# 0.17813345082933518
# 0.1425630949413046
# 0.13187243298012225
# 0.11703906793268541
# 0.11044291163893882
# 0.11020806196762686
# 0.10694929389416649
# 0.1062578101411532
# 0.10610022630555455
# 0.10201048277292121
# 0.10139427809144123
# 0.10108536708640792
# 0.1010853670864079
# 0.1010853670864079

# %% [markdown]
# You can also bypass TRAPI entirely and just use cypher to talk to the graph.  There are two instances.  There is one at http://robokopkg.renci.org which has a cypher browser on it, or you can write cypher and post it there.

# %%
from neo4j import GraphDatabase

# %%
pw=''
driver = GraphDatabase.driver('bolt://robokopkg.renci.org:7687', auth=('neo4j', pw))

# %%
#cypher = f'MATCH (a:`biolink:Gene`) RETURN a LIMIT 1'
cypher = f"MATCH (n0_0:`biolink:ChemicalEntity`)-[r0_0]-(n1_0:`biolink:Gene`)-[r1_0]-(n2_0:`biolink:DiseaseOrPhenotypicFeature`), (n0_1:`biolink:ChemicalEntity`)-[r0_1]-(n1_1:`biolink:BiologicalProcessOrActivity`)-[r1_1]-(n2_1:`biolink:DiseaseOrPhenotypicFeature`), (n0_2:`biolink:ChemicalEntity`)-[r0_2]-(n1_2:`biolink:Pathway`)-[r1_2]-(n2_2:`biolink:DiseaseOrPhenotypicFeature`) WHERE n1_0.name IN ['CYP2D6'] AND n0_0.name IN ['Buprenorphine'] AND n2_0.name IN ['Tremor'] AND n0_1.name IN ['Buprenorphine'] AND n2_1.name IN ['Tremor'] AND n0_2.name IN ['Buprenorphine'] AND n2_2.name IN ['Tremor'] RETURN * LIMIT 100"

with driver.session() as session:
    results = session.run(cypher)
    for result in results:
        print(result)

    #print(results)
    if (results) == 0:
        print("No results found")

# %% [markdown]
# You can also send the cypher through the automat interface instead:

# %%
j = {'query': cypher}
results = requests.post('https://automat.renci.org/robokopkg/cypher',json=j)

# %%
print(results.json())
# Out:
# {'results': [{'columns': ['n0_0', 'n0_1', 'n0_2', 'n1_0', 'n1_1', 'n1_2', 'n2_0', 'n2_1', 'n2_2', 'r0_0', 'r0_1', 'r0_2', 'r1_0', 'r1_1', 'r1_2'], 'data': []}], 'errors': []}
